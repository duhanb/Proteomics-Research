# %%
# Jason Luera
# Biopandas DF testing
# Trying to isolate columns in dataframes

# %%
# Importing Libraries
from biopandas.pdb import PandasPdb
import pandas as pd

# %%
ppdb = PandasPdb().fetch_pdb('1RD8')
ppdb.df['ATOM'].head()
# Out:
#   record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0        ATOM            1                 N                  GLU
# 1        ATOM            2                CA                  GLU
# 2        ATOM            3                 C                  GLU
# 3        ATOM            4                 O                  GLU
# 4        ATOM            5                CB                  GLU
#
#   chain_id  residue_number insertion  ... x_coord  y_coord  z_coord  \
# 0        A              10            ...  38.090  -19.145  117.028
# 1        A              10            ...  38.099  -17.888  116.277
# 2        A              10            ...  37.560  -18.108  114.844
# 3        A              10            ...  38.295  -18.463  113.885
# 4        A              10            ...  39.487  -17.307  116.239
#
#    occupancy  b_factor  blank_4 segment_id element_symbol charge  line_idx
# 0        1.0     51.63                                  N    NaN      1089
# ...

# %%
from biopandas.pdb import PandasPdb
ppdb = PandasPdb().fetch_pdb('1RD8')
sequence = ppdb.amino3to1()
sequence.tail()
# Out:
#       chain_id residue_name
# 11827        F            E
# 11836        F            E
# 11845        F            I
# 11853        F            D
# 11861        F            G

# %%
ppdb.df['ATOM'].head(2)
# Out:
#   record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0        ATOM            1                 N                  GLU
# 1        ATOM            2                CA                  GLU
#
#   chain_id  residue_number insertion  ... x_coord  y_coord  z_coord  \
# 0        A              10            ...  38.090  -19.145  117.028
# 1        A              10            ...  38.099  -17.888  116.277
#
#    occupancy  b_factor  blank_4 segment_id element_symbol charge  line_idx
# 0        1.0     51.63                                  N    NaN      1089
# 1        1.0     54.72                                  C    NaN      1090
#
# [2 rows x 21 columns]

# %%
# Isolation of 2 columns
atombfactordf = ppdb(1,len(ppdb)+1)['ATOM']['b_factor']
atombfactordf
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-8b65531741e3> in <module>
#       1 # Isolation of 2 columns
# ----> 2 atombfactordf = ppdb(1,len(ppdb)+1)['ATOM']['b_factor']
#       3 atombfactordf
#
# TypeError: object of type 'PandasPdb' has no len()

# %%
ppdb.df['ATOM'][ppdb.df['ATOM']['atom_number'] != 0].head()
# Out:
#   record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0        ATOM            1                 N                  GLU
# 1        ATOM            2                CA                  GLU
# 2        ATOM            3                 C                  GLU
# 3        ATOM            4                 O                  GLU
# 4        ATOM            5                CB                  GLU
#
#   chain_id  residue_number insertion  ... x_coord  y_coord  z_coord  \
# 0        A              10            ...  38.090  -19.145  117.028
# 1        A              10            ...  38.099  -17.888  116.277
# 2        A              10            ...  37.560  -18.108  114.844
# 3        A              10            ...  38.295  -18.463  113.885
# 4        A              10            ...  39.487  -17.307  116.239
#
#    occupancy  b_factor  blank_4 segment_id element_symbol charge  line_idx
# 0        1.0     51.63                                  N    NaN      1089
# ...

# %%
ppdb = PandasPdb().fetch_pdb('1RD8')
ppdb.df['ATOM'].head()
cols = ppdb.columns
print(cols)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-a7839fdf2172> in <module>
#       1 ppdb = PandasPdb().fetch_pdb('1RD8')
#       2 ppdb.df['ATOM'].head()
# ----> 3 cols = ppdb.columns
#       4 print(cols)
#
# AttributeError: 'PandasPdb' object has no attribute 'columns'
