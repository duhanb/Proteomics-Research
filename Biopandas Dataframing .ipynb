# %%
# Jason Luera
# Biopandas DF testing
# Trying to isolate columns in dataframes

# %%
# Importing Libraries
from biopandas.pdb import PandasPdb
import pandas as pd

# %%
ppdb = PandasPdb().fetch_pdb('1RD8')
ppdb.df['ATOM'].head()
# Out:
#   record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0        ATOM            1                 N                  GLU
# 1        ATOM            2                CA                  GLU
# 2        ATOM            3                 C                  GLU
# 3        ATOM            4                 O                  GLU
# 4        ATOM            5                CB                  GLU
#
#   chain_id  residue_number insertion  ... x_coord  y_coord  z_coord  \
# 0        A              10            ...  38.090  -19.145  117.028
# 1        A              10            ...  38.099  -17.888  116.277
# 2        A              10            ...  37.560  -18.108  114.844
# 3        A              10            ...  38.295  -18.463  113.885
# 4        A              10            ...  39.487  -17.307  116.239
#
#    occupancy  b_factor  blank_4 segment_id element_symbol charge  line_idx
# 0        1.0     51.63                                  N    NaN      1089
# ...

# %%
from biopandas.pdb import PandasPdb
ppdb = PandasPdb().fetch_pdb('1RD8')
sequence = ppdb.amino3to1()
sequence.tail()
# Out:
#       chain_id residue_name
# 11827        F            E
# 11836        F            E
# 11845        F            I
# 11853        F            D
# 11861        F            G

# %%
ppdb.df['ATOM'].head(2)
# Out:
#   record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0        ATOM            1                 N                  GLU
# 1        ATOM            2                CA                  GLU
#
#   chain_id  residue_number insertion  ... x_coord  y_coord  z_coord  \
# 0        A              10            ...  38.090  -19.145  117.028
# 1        A              10            ...  38.099  -17.888  116.277
#
#    occupancy  b_factor  blank_4 segment_id element_symbol charge  line_idx
# 0        1.0     51.63                                  N    NaN      1089
# 1        1.0     54.72                                  C    NaN      1090
#
# [2 rows x 21 columns]

# %%
# Isolation of 2 columns
atombfactordf = ppdb.df['ATOM']['b_factor'].head()
atombfactordf
# Out:
# 0    51.63
# 1    54.72
# 2    47.63
# 3    45.41
# 4    59.04
# Name: b_factor, dtype: float64

# %%
ppdb.df['ATOM'][ppdb.df['ATOM']['atom_number'] != 0].head()
# Out:
#   record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0        ATOM            1                 N                  GLU
# 1        ATOM            2                CA                  GLU
# 2        ATOM            3                 C                  GLU
# 3        ATOM            4                 O                  GLU
# 4        ATOM            5                CB                  GLU
#
#   chain_id  residue_number insertion  ... x_coord  y_coord  z_coord  \
# 0        A              10            ...  38.090  -19.145  117.028
# 1        A              10            ...  38.099  -17.888  116.277
# 2        A              10            ...  37.560  -18.108  114.844
# 3        A              10            ...  38.295  -18.463  113.885
# 4        A              10            ...  39.487  -17.307  116.239
#
#    occupancy  b_factor  blank_4 segment_id element_symbol charge  line_idx
# 0        1.0     51.63                                  N    NaN      1089
# ...

# %%
# Printing keys
# Keys are coordinates of entries from that perspective
ppdb.df.keys()
# Out:
# dict_keys(['ATOM', 'HETATM', 'ANISOU', 'OTHERS'])

# %%
# Printing the columns of ATOM
ppdb.df['ATOM'].head()
# Use head so you don't have to process the whole file in jupyter
# Out:
#   record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0        ATOM            1                 N                  GLU
# 1        ATOM            2                CA                  GLU
# 2        ATOM            3                 C                  GLU
# 3        ATOM            4                 O                  GLU
# 4        ATOM            5                CB                  GLU
#
#   chain_id  residue_number insertion  ... x_coord  y_coord  z_coord  \
# 0        A              10            ...  38.090  -19.145  117.028
# 1        A              10            ...  38.099  -17.888  116.277
# 2        A              10            ...  37.560  -18.108  114.844
# 3        A              10            ...  38.295  -18.463  113.885
# 4        A              10            ...  39.487  -17.307  116.239
#
#    occupancy  b_factor  blank_4 segment_id element_symbol charge  line_idx
# 0        1.0     51.63                                  N    NaN      1089
# ...

# %%
# Looking at the columns of ATOM
ppdb.df['ATOM'].columns
# Out:
# Index(['record_name', 'atom_number', 'blank_1', 'atom_name', 'alt_loc',
#        'residue_name', 'blank_2', 'chain_id', 'residue_number', 'insertion',
#        'blank_3', 'x_coord', 'y_coord', 'z_coord', 'occupancy', 'b_factor',
#        'blank_4', 'segment_id', 'element_symbol', 'charge', 'line_idx'],
#       dtype='object')

# %%
# Isolating from Row 1
ppdb.df['ATOM'][ppdb.df['ATOM']['atom_number'] != 0].head()
# Out:
#   record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0        ATOM            1                 N                  GLU
# 1        ATOM            2                CA                  GLU
# 2        ATOM            3                 C                  GLU
# 3        ATOM            4                 O                  GLU
# 4        ATOM            5                CB                  GLU
#
#   chain_id  residue_number insertion  ... x_coord  y_coord  z_coord  \
# 0        A              10            ...  38.090  -19.145  117.028
# 1        A              10            ...  38.099  -17.888  116.277
# 2        A              10            ...  37.560  -18.108  114.844
# 3        A              10            ...  38.295  -18.463  113.885
# 4        A              10            ...  39.487  -17.307  116.239
#
#    occupancy  b_factor  blank_4 segment_id element_symbol charge  line_idx
# 0        1.0     51.63                                  N    NaN      1089
# ...

# %% [markdown]
# ## Data Conditioning Objective
# ### Clean up dataframe
# ### Must start at atom number 1
# ### Remove empty columns
# #### *Need record_name, atom_number, atom_name, residue_name, chain_id, residue_number, b_factor, charge, line_idx

# %%
stripped = ppdb.df['ATOM'][ppdb.df['ATOM'].drop(columns=['blank_1'])]
# This unique error lets me know that the data columns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-e4b4874aff14> in <module>
# ----> 1 stripped = ppdb.df['ATOM'][ppdb.df['ATOM'].drop(columns=['blank_1'])]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2912         # Do we have a (boolean) DataFrame?
#    2913         if isinstance(key, DataFrame):
# -> 2914             return self._getitem_frame(key)
#    2915
#    2916         # Do we have a (boolean) 1d indexer?
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_frame(self, key)
#    3007     def _getitem_frame(self, key):
#    3008         if key.values.size and not is_bool_dtype(key.values):
# -> 3009             raise ValueError('Must pass DataFrame with boolean values only')
#    3010         return self.where(key)
#    3011
#
# ...

# %%
# Saving Dataframe as a Pandas accessible object
df = pd.DataFrame(ppdb.df['ATOM'])
df1 = df.copy()
df1.head()
# Out:
#   record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0        ATOM            1                 N                  GLU
# 1        ATOM            2                CA                  GLU
# 2        ATOM            3                 C                  GLU
# 3        ATOM            4                 O                  GLU
# 4        ATOM            5                CB                  GLU
#
#   chain_id  residue_number insertion  ... x_coord  y_coord  z_coord  \
# 0        A              10            ...  38.090  -19.145  117.028
# 1        A              10            ...  38.099  -17.888  116.277
# 2        A              10            ...  37.560  -18.108  114.844
# 3        A              10            ...  38.295  -18.463  113.885
# 4        A              10            ...  39.487  -17.307  116.239
#
#    occupancy  b_factor  blank_4 segment_id element_symbol charge  line_idx
# 0        1.0     51.63                                  N    NaN      1089
# ...

# %%
df1.columns
# Out:
# Index(['record_name', 'atom_number', 'blank_1', 'atom_name', 'alt_loc',
#        'residue_name', 'blank_2', 'chain_id', 'residue_number', 'insertion',
#        'blank_3', 'x_coord', 'y_coord', 'z_coord', 'occupancy', 'b_factor',
#        'blank_4', 'segment_id', 'element_symbol', 'charge', 'line_idx'],
#       dtype='object')

# %%
df1.drop(['blank_1', 'alt_loc', 'blank_2', 'insertion',
         'blank_3', 'x_coord', 'y_coord', 'z_coord',
         'blank_4'], axis=1)
df1
# Out:
#       record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0            ATOM            1                 N                  GLU
# 1            ATOM            2                CA                  GLU
# 2            ATOM            3                 C                  GLU
# 3            ATOM            4                 O                  GLU
# 4            ATOM            5                CB                  GLU
# 5            ATOM            6                CG                  GLU
# 6            ATOM            7                CD                  GLU
# 7            ATOM            8               OE1                  GLU
# 8            ATOM            9               OE2                  GLU
# 9            ATOM           10                 N                  ASP
# 10           ATOM           11                CA                  ASP
# 11           ATOM           12                 C                  ASP
# ...

# %%
# Mean b_factor
df1.columns
meanb = df1['b_factor'].mean()
print(meanb)
# Out:
# 42.40261778339668
